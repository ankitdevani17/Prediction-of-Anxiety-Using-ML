# %% [markdown]
# Mulitple linear regression

# %% [markdown]
# State Anxiety

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import io
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.linear_model import LinearRegression

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-349ea484-83e6-48db-b985-6010b1e3a13e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-349ea484-83e6-48db-b985-6010b1e3a13e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-49432676dcaa> in <module>()
#       1 from google.colab import files
# ----> 2 uploaded=files.upload()
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in upload()
#      62   result = _output.eval_js(
#      63       'google.colab._files._uploadFiles("{input_id}", "{output_id}")'.format(
# ---> 64           input_id=input_id, output_id=output_id))
# ...

# %%
df = pd.read_csv(io.BytesIO(uploaded['Multiple.csv']))
df.head()
# Out:
#    SA   BP        RM        LH
# 0  30  108 -0.000023  0.042070
# 1  21  120 -0.000040  0.050306
# 2  25  116 -0.000074 -0.019960
# 3  26  118 -0.000039 -0.145620
# 4  30  132 -0.000041 -0.089641

# %%
X  = df[['BP','RM','LH']]
y= df['SA']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# fit a model
lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
predictions = lm.predict(X_test)

# %%
model.score(X, y)
# Out:
# 0.6263549122088545

# %%
# compute with statsmodels, by adding intercept manually
import statsmodels.api as sm
X1 = sm.add_constant(X)
result = sm.OLS(y, X1).fit()
#print dir(result)
print (result.rsquared, result.rsquared_adj)
# 0.877643371323 0.863248473832()
# Out:
# 0.6312024351035652 0.6199127137291847

# %%
model.coef_
# Out:
# array([2.31946505e-01, 1.04850460e+04, 2.86679288e+01])

# %%
model.intercept_
# Out:
# 7.195770854513455

# %%
# %matplotlib inline
plt.xlabel('BP')
plt.ylabel('SA')
plt.scatter(df.BP,df.SA,color='red',marker='+')
plt.scatter(df.LH,df.SA,color='yellow',marker='+')
plt.scatter(df.RM,df.SA,color='black',marker='+')

# %% [markdown]
# Trait Anxiety

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import io
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-e260e7fa-9796-4c49-b82e-628a63b83d1b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e260e7fa-9796-4c49-b82e-628a63b83d1b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Trait3 - Sheet1.csv to Trait3 - Sheet1 (1).csv

# %%
df = pd.read_csv(io.BytesIO(uploaded['Trait3 - Sheet1.csv']))
df.head()
# Out:
#    EST  EXT  Anx
# 0   -6   16    2
# 1   -5  -10    3
# 2   -4   -5    3
# 3   -1   -4    3
# 4  -11   -1    3

# %%
X  = df[['EST','EXT']]
y= df['Anx']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# fit a model
lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
predictions = lm.predict(X_test)
# compute with statsmodels, by adding intercept manually
import statsmodels.api as sm
X1 = sm.add_constant(X)
result = sm.OLS(y, X1).fit()
#print dir(result)
print (result.rsquared, result.rsquared_adj)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# 0.5321098328815674 0.5320358054838745

# %%
# %matplotlib inline
plt.xlabel('EST(RED) and EXT(YELLOW)')
plt.ylabel('Trait Anxiety')
plt.scatter(df.EST,df.Anx,color='red',marker='+')
plt.scatter(df.EXT,df.Anx,color='yellow',marker='+')

# %% [markdown]
# Cross Validation Approach

# %%
# importing libraries
import numpy as np
from sklearn.model_selection import LeaveOneOut

# Independent variable
print("\nIndependent variable :")
print(X)

# Dependent variable
print("\nDependent variable :")
print(y)

# creating the leav one out function
loo = LeaveOneOut()
loo.get_n_splits(X)



## NOTE: you can try out other validation techniques as well in this live coding window
# Out:
# Independent variable :
#        EST  EXT
# 0       -6   16
# 1       -5  -10
# 2       -4   -5
# 3       -1   -4
# 4      -11   -1
# ...    ...  ...
# 12639   14   -8
# 12640    6   -1
# 12641    9   -4
# 12642   -5    3
# 12643  -11   18
#
# [12644 rows x 2 columns]
#
# Dependent variable :
# 0        2
# 1        3
# 2        3
# 3        3
# 4        3
#         ..
# 12639    3
# 12640    3
# 12641    3
# 12642    2
# 12643    2
# Name: Anx, Length: 12644, dtype: int64
# 12644
